# %%
#<class tupple>

# %%
# creatin a tuple with integer
l1=(1,2,3,4,5)
print(l1)
# Out:
# (1, 2, 3, 4, 5)

# %%
# accessing items of tuple
a=(1,2,3,4,5)
print(a)
print(a[2])
# Out:
# (1, 2, 3, 4, 5)
# 3

# %%
#creating tuple with float.
b=(6,5,5,9,2,0)
print(b)
# Out:
# (6, 5, 5, 9, 2, 0)

# %%
#creating tuple with string
c=("one","two","three")
print(c)
# Out:
# ('one', 'two', 'three')

# %%
#creating tuple multiple data type
mix=(1,"hello",3.4)
print(mix)
# Out:
# (1, 'hello', 3.4)

# %%
#accessing item of tuple
a=(1,2,3,4,5,"hello")
print(a)
print(a[2])
# Out:
# (1, 2, 3, 4, 5, 'hello')
# 3

# %%
#create a dictionary
a={
    "name":"ram",
    "age":20,
    "education":"BCA"}
print(a)
# Out:
# {'name': 'ram', 'age': 20, 'education': 'BCA'}

# %%
type(a)
# Out:
# dict

# %%
len(a)
# Out:
# 3

# %%
x=a.keys()
print(x)
# Out:
# dict_keys(['name', 'age', 'education'])

# %%
y=a.values()
print(y)
# Out:
# dict_values(['ram', 20, 'BCA'])

# %%
dict={"name":"ram","age":20,"education":"BCA"}
print(dict)
# Out:
# {'name': 'ram', 'age': 20, 'education': 'BCA'}

# %%
z=a.items()
print(z)
# Out:
# dict_items([('name', 'ram'), ('age', 20), ('education', 'BCA')])

# %%
#example
set1={1,2,3,4}
print(set1)
# Out:
# {1, 2, 3, 4}

# %%
#3 duplicates not allowed
set={1,2,3,4,5,6,7,1,1}
print(set)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
len(set)
# Out:
# 7

# %%
type(set)
# Out:
# set
